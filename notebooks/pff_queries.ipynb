# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from gql import Client, gql
from gql.transport.httpx import HTTPXTransport
import os
from tqdm.auto import tqdm
import pandas as pd

# %%
GQL_CLIENT_TIMEOUT = 60
RAW_DATA_PATH = '../data/raw/PL-22-23'

# %%
from gandula.providers.pff.api.api_client import execute_query, get_client

api_url = os.getenv('api_url')
api_key = os.getenv('api_key')
client = get_client(api_url, api_key)

# %% [markdown]
# # Queries

# %%
get_players = """
query rosters($gameId: ID!)  {
  rosters(gameId: $gameId) {
    positionGroupType
    player {
      id
      firstName
      lastName
      nickname
    }
    shirtNumber
    team {
      id
    }
    game {
      id
    }
  }
}
"""

# %%
get_game = """
query game($id: ID!) {
  game(id: $id) {
     homeTeam {
      id
      name
    }
    awayTeam {
      id
      name
    }
    competition {
      id
      name
    }
    date
    homeTeamStartLeft
    id
    season
    week
  }
}
"""

# %%
get_teams = """
query game($id: ID!) {
  game(id: $id) {
    id
    homeTeam  {
      id
      name
      shortName
      country
      kits {
        name 
        primaryColor
        primaryTextColor
        secondaryColor
        secondaryTextColor
        updatedAt 
      }
    }
  }
}

"""

# %%
get_game_players = """
query game($id: ID!) {
  game(id: $id) {
    id
    rosters {
      positionGroupType
      player {
        id
        firstName
        lastName
        nickname
      }
      shirtNumber
      team {
        id
      }
    }
  }
}
"""

# %%
games = os.listdir(RAW_DATA_PATH)
game_ids = [game.split('.')[0] for game in games]
print(f"Games to process: {len(game_ids)}")
# Out:
# Games to process: 190

# %%
import time

games = []
teams = []
team_ids = []
players = []
player_ids = []

for game_id in tqdm(game_ids, desc='Processing games', total=len(game_ids)):
    variables = {'id': int(game_id)}
    player_variables = {'gameId': int(game_id)}

    # game_result = client.execute(
    #         gql(get_game),
    #         variable_values=variables,
    #         serialize_variables=True,
    #         parse_result=True,
    #     )
    
    # games.append(game_result['game'])

    # teams_result = client.execute(
    #         gql(get_teams),
    #         variable_values=variables,
    #         serialize_variables=True,
    #         parse_result=True,
    #     )
    
    # if teams_result['game']['homeTeam']['id'] not in team_ids:
    #     teams.append(teams_result['game'])
    #     team_ids.append(teams_result['game']['homeTeam']['id'])

    players_result = client.execute(
            gql(get_game_players),
            variable_values=variables,
            serialize_variables=True,
            parse_result=True,
        )
    
    players.append(players_result['game'])

    time.sleep(1)
# Out:
# Processing games:   0%|          | 0/190 [00:00<?, ?it/s]

# %%
def games_to_df(games):
    
    games_list = []

    for game in games:

        games_list.append({
            'match_id': int(game['id']),
            'season': game['season'],
            'week': int(game['week']),
            'date': pd.to_datetime(game['date']),
            'home_team_id': int(game['homeTeam']['id']),
            'home_team_name': game['homeTeam']['name'],
            'away_team_id': int(game['awayTeam']['id']),
            'away_team_name': game['awayTeam']['name'],
            'competition_id': int(game['competition']['id']),
            'competition_name': game['competition']['name'],
            'home_team_start_left': game['homeTeamStartLeft']
    
        })

    return pd.DataFrame(games_list).sort_values(by='match_id').reset_index(drop=True)

# %%
def teams_to_df(teams):
    
    teams_list = []

    for team in teams:

        kits = team['homeTeam']['kits']  # lista de dicionários

        # 1) Filtrar apenas kits com name=='home'
        home_kits = [k for k in kits if k['name'].lower() == 'home']
        
        if home_kits:
            # Ordenar pelos updatedAt (ISO 8601) em ordem decrescente
            home_kits.sort(key=lambda x: x['updatedAt'], reverse=True)
            chosen_kit = home_kits[0]  # mais recente
        else:
            # 2) Se não existir kit 'home', usar o kit mais recente entre todos
            kits.sort(key=lambda x: x['updatedAt'], reverse=True)
            chosen_kit = kits[0]  # mais recente no geral

        primary_color = chosen_kit['primaryColor']
        secondary_color = chosen_kit['secondaryColor']

        teams_list.append({
            'team_id': int(team['homeTeam']['id']),
            'team_name': team['homeTeam']['name'],
            'team_short_name': team['homeTeam']['shortName'],
            'team_country': team['homeTeam']['country'],
            'primary_color': primary_color,
            'secondary_color': secondary_color
        })

    return pd.DataFrame(teams_list).drop_duplicates(subset=['team_id']).sort_values('team_id').reset_index(drop=True)

# %%
def players_to_df(players_game_rosters):
    
    players_list = []
    print(players_game_rosters)



    for game_roster in players_game_rosters:
        match_id = game_roster['id']
        players_rosters = game_roster['rosters']

        for player in players_rosters:

            players_list.append({
                'player_id': int(player['player']['id']),
                'first_name': player['player']['firstName'],
                'last_name': player['player']['lastName'],
                'nickname': player['player']['nickname'],
                'team_id': int(player['team']['id']),
                'position': player['positionGroupType'],
                'shirt_number': player['shirtNumber'],
                'match_id': int(match_id)
            })

    return pd.DataFrame(players_list).drop_duplicates(subset=['player_id','team_id','match_id']).sort_values('player_id').reset_index(drop=True)

# %%
# games_df = games_to_df(games)
# games_df

# %%
# teams_df = teams_to_df(teams)
# teams_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10916\1963903552.py in ?()
# ----> 1 teams_df = teams_to_df(teams)
#       2 teams_df
#
# ~\AppData\Local\Temp\ipykernel_10916\2112790782.py in ?(teams)
#      29             'primary_color': primary_color,
#      30             'secondary_color': secondary_color
#      31         })
#      32
# ---> 33     return pd.DataFrame(teams_list).drop_duplicates(subset=['team_id']).sort_values('team_id').reset_index(drop=True)
#
# c:\Users\jllgo\OneDrive\Documentos\UFMG\MSc & MSI 2\MatchSegmentation\.venv\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# c:\Users\jllgo\OneDrive\Documentos\UFMG\MSc & MSI 2\MatchSegmentation\.venv\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'team_id'

# %%
players_df = players_to_df(players)
players_df
# Out:
# [{'id': '4436', 'rosters': [{'player': {'firstName': 'Luka', 'id': '473', 'lastName': 'Milivojevic', 'nickname': 'Luka Milivojevic'}, 'positionGroupType': 'DM', 'shirtNumber': '4', 'team': {'id': '7'}}, {'player': {'firstName': 'Oleksandr', 'id': '15', 'lastName': 'Zinchenko', 'nickname': 'Oleksandr Zinchenko'}, 'positionGroupType': 'LB', 'shirtNumber': '35', 'team': {'id': '2'}}, {'player': {'firstName': 'Eberechi', 'id': '1940', 'lastName': 'Eze', 'nickname': 'Eberechi Eze'}, 'positionGroupType': 'AM', 'shirtNumber': '10', 'team': {'id': '7'}}, {'player': {'firstName': 'Reiss', 'id': '165', 'lastName': 'Nelson', 'nickname': 'Reiss Nelson'}, 'positionGroupType': 'RW', 'shirtNumber': '24', 'team': {'id': '2'}}, {'player': {'firstName': 'Vicente', 'id': '461', 'lastName': 'Guaita', 'nickname': 'Vicente Guaita'}, 'positionGroupType': 'GK', 'shirtNumber': '13', 'team': {'id': '7'}}, {'player': {'firstName': 'Jeffrey', 'id': '477', 'lastName': 'Schlupp', 'nickname': 'Jeffrey Schlupp'}, 'positionGroupType': 'CM', 'shirtNumber': '15', 'team': {'id': '7'}}, {'player': {'firstName': 'Mohamed', 'id': '1898', 'lastName': 'Elneny', 'nickname': 'Mohamed Elneny'}, 'positionGroupType': 'DM', 'shirtNumber': '25', 'team': {'id': '2'}}, {'player': {'firstName': 'Nicolas', 'id': '164', 'lastName': 'Pépé', 'nickname': 'Nicolas Pépé'}, 'positionGroupType': 'RW', 'shirtNumber': '19', 'team': {'id': '2'}}, {'player': {'firstName': 'Bukayo', 'id': '163', 'lastName': 'Saka', 'nickname': 'Bukayo Saka'}, 'positionGroupType': 'RW', 'shirtNumber': '7', 'team': {'id': '2'}}, {'player': {'firstName': 'Jairo', 'id': '467', 'lastName': 'Riedewald', 'nickname': 'Jairo Riedewald'}, 'positionGroupType': 'DM', 'shirtNumber': '44', 'team': {'id': '7'}}, {'player': {'firstName': 'Thomas', 'id': '1380', 'lastName': 'Partey', 'nickname': 'Thomas Partey'}, 'positionGroupType': 'CM', 'shirtNumber': '5', 'team': {'id': '2'}}, {'player': {'firstName': 'Jean-Philippe', 'id': '2127', 'lastName': 'Mateta', 'nickname': 'Jean-Philippe Mateta'}, 'positionGroupType': 'CF', 'shirtNumber': '14', 'team': {'id': '7'}}, {'player': {'firstName': 'William', 'id': '1895', 'lastName': 'Saliba', 'nickname': 'William Saliba'}, 'positionGroupType': 'RCB', 'shirtNumber': '12', 'team': {'id': '2'}}, {'player': {'firstName': 'Joel', 'id': '471', 'lastName': 'Ward', 'nickname': 'Joel Ward'}, 'positionGroupType': 'RB', 'shirtNumber': '2', 'team': {'id': '7'}}, {'player': {'firstName': 'Wilfried', 'id': '480', 'lastName': 'Zaha', 'nickname': 'Wilfried Zaha'}, 'positionGroupType': 'LW', 'shirtNumber': '11', 'team': {'id': '7'}}, {'player': {'firstName': 'Gabriel', 'id': '1894', 'lastName': 'Magalháes', 'nickname': 'Gabriel'}, 'positionGroupType': 'LCB', 'shirtNumber': '6', 'team': {'id': '2'}}, {'player': {'firstName': 'Luke', 'id': '7114', 'lastName': 'Plange', 'nickname': 'Luke Plange'}, 'positionGroupType': 'CF', 'shirtNumber': '48', 'team': {'id': '7'}}, {'player': {'firstName': 'Ben', 'id': '1916', 'lastName': 'White', 'nickname': 'Ben White'}, 'positionGroupType': 'RB', 'shirtNumber': '4', 'team': {'id': '2'}}, {'player': {'firstName': 'Cédric', 'id': '390', 'lastName': 'Soares', 'nickname': 'Cédric Soares'}, 'positionGroupType': 'RB', 'shirtNumber': '17', 'team': {'id': '2'}}, {'player': {'firstName': 'Granit', 'id': '157', 'lastName': 'Xhaka', 'nickname': 'Granit Xhaka'}, 'positionGroupType': 'CM', 'shirtNumber': '34', 'team': {'id': '2'}}, {'player': {'firstName': 'Odsonne', 'id': '6016', 'lastName': 'Edouard', 'nickname': 'Odsonne Edouard'}, 'positionGroupType': 'CF', 'shirtNumber': '22', 'team': {'id': '7'}}, {'player': {'firstName': 'Albert Sambi', 'id': '5045', 'lastName': 'Lokonga', 'nickname': 'Albert Sambi Lokonga'}, 'positionGroupType': 'CM', 'shirtNumber': '23', 'team': {'id': '2'}}, {'player': {'firstName': 'Aaron', 'id': '281', 'lastName': 'Ramsdale', 'nickname': 'Aaron Ramsdale'}, 'positionGroupType': 'GK', 'shirtNumber': '1', 'team': {'id': '2'}}, {'player': {'firstName': ' ...
#       player_id first_name    last_name            nickname  team_id position  \
# 0             1      Harry         Kane          Harry Kane       17       CF
# 1             1      Harry         Kane          Harry Kane       17       CF
# 2             1      Harry         Kane          Harry Kane       17       CF
# 3             1      Harry         Kane          Harry Kane       17       CF
# 4             1      Harry         Kane          Harry Kane       17       CF
# ...         ...        ...          ...                 ...      ...      ...
# 7590      15630       Paul      Onuachu        Paul Onuachu       16       CF
# 7591      15632     Victor  Kristiansen  Victor Kristiansen        9       LB
# 7592      16785       João        Gomes          João Gomes       20       CM
# 7593      16786      Yasin        Ayari         Yasin Ayari        4       CM
# 7594      18274  Sebastian        Revan     Sebastian Revan        3       LB
#
#      shirt_number  match_id
# 0              10      4481
# 1              10      4593
# 2              10      4544
# 3              10      4613
# 4              10      4503
# ...           ...       ...
# 7590           12      4504
# 7591           16      4501
# 7592           35      4502
# 7593           26      4496
# 7594           56      4501
#
# [7595 rows x 8 columns]

# %%
players_df[players_df['match_id'] == 4625]
# Out:
#       player_id first_name       last_name                nickname  team_id  \
# 609          72      Serge          Aurier            Serge Aurier      221
# 615          73       Kyle   Walker-Peters      Kyle Walker-Peters       16
# 723          89      Willy       Caballero         Willy Caballero       16
# 1204        154    Ainsley  Maitland-Niles  Ainsley Maitland-Niles       16
# 1782        230      Willy            Boly              Willy Boly      221
# 1942        243     Morgan     Gibbs-White      Morgan Gibbs-White      221
# 2283        285      Steve            Cook              Steve Cook      221
# 2479        314        Sam        Surridge            Sam Surridge      221
# 2575        334       Jack         Colback            Jack Colback      221
# 2923        394      James     Ward-Prowse       James Ward-Prowse       16
# 2950        396     Stuart       Armstrong        Stuart Armstrong       16
# 2977        399     Moussa         Djenepo          Moussa Djenepo       16
# 2993        400    Mohamed     Elyounoussi     Mohamed Elyounoussi       16
# 3028        403        Che           Adams               Che Adams       16
# 3361        462      Wayne       Hennessey         Wayne Hennessey      221
# 3600        509       Dean       Henderson          Dean Henderson      221
# 3709        589       Neco        Williams           Neco Williams      221
# 3851       1374      Renan            Lodi              Renan Lodi      221
# 4293       1910   Mohammed          Salisu         Mohammed Salisu       16
# 4476       1958      Taiwo         Awoniyi           Taiwo Awoniyi      221
# 4944       2070   Ibrahima          Diallo         Ibrahima Diallo       16
# 5306       3972       Duje      Caleta-Car         Duje Caleta-Car       16
# 5389       4282      Sékou            Mara              Sékou Mara       16
# 5491       4630      Armel   Bella-Kotchap     Armel Bella-Kotchap       16
# 5570       4927       Orel         Mangala            Orel Mangala      221
# 6049       5114     Romain         Perraud          Romain Perraud       16
# 6082       5128   Emmanuel          Dennis         Emmanuel Dennis      221
# 6148       5137       Adam       Armstrong          Adam Armstrong       16
# 6252       5960     Lyanco        Vojnovic                  Lyanco       16
# 6377       6134      Romeo           Lavia             Romeo Lavia       16
# 6411       6656     Samuel          Edozie           Samuel Edozie       16
# 6552       7001       Ryan           Yates              Ryan Yates      221
# 6579       7002      Scott         McKenna           Scott McKenna      221
# 6580       7003        Joe         Worrall             Joe Worrall      221
# 6626       7008    Brennan         Johnson         Brennan Johnson      221
# 6755       7174      Harry         Toffolo           Harry Toffolo      221
# 7096       8328       Remo         Freuler            Remo Freuler      221
# 7188       9990      Gavin          Bazunu            Gavin Bazunu       16
# 7199       9992        Joe           Aribo               Joe Aribo       16
# 7584      14116    Gustavo          Scarpa          Gustavo Scarpa      221
#
#      position shirt_number  match_id
# 609        RB           24      4625
# 615       RWB            2      4625
# 723        GK           13      4625
# 1204       RM            3      4625
# 1782      LCB           30      4625
# 1942       AM           10      4625
# 2283      RCB            3      4625
# 2479       CF           16      4625
# 2575       DM            8      4625
# 2923       CM            8      4625
# 2950       CM           17      4625
# 2977       LW           19      4625
# 2993       CM           24      4625
# 3028       CF           10      4625
# 3361       GK           13      4625
# 3600       GK            1      4625
# 3709       RB            7      4625
# 3851       LB           32      4625
# 4293      LCB           22      4625
# 4476       CF            9      4625
# 4944       DM           27      4625
# 5306      RCB            6      4625
# 5389       CF           18      4625
# 5491      RCB           37      4625
# 5570       CM            5      4625
# 6049      LWB           15      4625
# 6082       CF           25      4625
# 6148       CF            9      4625
# 6252      MCB            4      4625
# 6377       DM           45      4625
# 6411       LW           23      4625
# 6552       CM           22      4625
# 6579      LCB           26      4625
# 6580      RCB            4      4625
# 6626       CF           20      4625
# 6755       LB           15      4625
# 7096       CM           23      4625
# 7188       GK           31      4625
# 7199       CM            7      4625
# 7584       AM           31      4625

# %% [markdown]
# # Export CSV

# %%
#games_df.to_csv('../data/csv/games.csv', index=False)
#teams_df.to_csv('../data/csv/teams.csv', index=False)
players_df.to_csv('../data/csv/players_matches.csv', index=False)
